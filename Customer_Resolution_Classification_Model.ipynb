# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\USER\Downloads\Datasets\Call-Center-Dataset.xlsx")
df.head()
# Out:
#   Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0  ID0001    Diane  2021-01-01  09:12:58   Contract related              Y
# 1  ID0002    Becky  2021-01-01  09:12:58  Technical Support              Y
# 2  ID0003  Stewart  2021-01-01  09:47:31   Contract related              Y
# 3  ID0004     Greg  2021-01-01  09:47:31   Contract related              Y
# 4  ID0005    Becky  2021-01-01  10:00:29    Payment related              Y
#
#   Resolved  Speed of answer in seconds AvgTalkDuration  Satisfaction rating  \
# 0        Y                       109.0        00:02:23                  3.0
# 1        N                        70.0        00:04:02                  3.0
# 2        Y                        10.0        00:02:11                  3.0
# 3        Y                        53.0        00:00:37                  2.0
# 4        Y                        95.0        00:01:00                  3.0
#
#    Unnamed: 10  Unnamed: 11 Unnamed: 12
# ...

# %%
for i in df.columns:
    print(i,':','\n',df[i].unique())
# Out:
# Call Id :
#  ['ID0001' 'ID0002' 'ID0003' ... 'ID4998' 'ID4999' 'ID5000']
# Agent :
#  ['Diane' 'Becky' 'Stewart' 'Greg' 'Jim' 'Joe' 'Martha' 'Dan']
# Date :
#  ['2021-01-01' '2021-01-02' '2021-01-03' '2021-01-04' '2021-01-05'
#  '2021-01-06' '2021-01-07' '2021-01-08' '2021-01-09' '2021-01-10'
#  '2021-01-11' '2021-01-12' '2021-01-13' '2021-01-14' '2021-01-15'
#  '2021-01-16' '2021-01-17' '2021-01-18' '2021-01-19' '2021-01-20'
#  '2021-01-21' '2021-01-22' '2021-01-23' '2021-01-24' '2021-01-25'
#  '2021-01-26' '2021-01-27' '2021-01-28' '2021-01-29' '2021-01-30'
#  '2021-01-31' '2021-02-01' '2021-02-02' '2021-02-03' '2021-02-04'
#  '2021-02-05' '2021-02-06' '2021-02-07' '2021-02-08' '2021-02-09'
#  '2021-02-10' '2021-02-11' '2021-02-12' '2021-02-13' '2021-02-14'
#  '2021-02-15' '2021-02-16' '2021-02-17' '2021-02-18' '2021-02-19'
#  '2021-02-20' '2021-02-21' '2021-02-22' '2021-02-23' '2021-02-24'
#  '2021-02-25' '2021-02-26' '2021-02-27' '2021-02-28' '2021-03-01'
# ...

# %%
df.drop(columns=['Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'], inplace=True)

# %%
df.head()
# Out:
#   Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0  ID0001    Diane  2021-01-01  09:12:58   Contract related              Y
# 1  ID0002    Becky  2021-01-01  09:12:58  Technical Support              Y
# 2  ID0003  Stewart  2021-01-01  09:47:31   Contract related              Y
# 3  ID0004     Greg  2021-01-01  09:47:31   Contract related              Y
# 4  ID0005    Becky  2021-01-01  10:00:29    Payment related              Y
#
#   Resolved  Speed of answer in seconds AvgTalkDuration  Satisfaction rating
# 0        Y                       109.0        00:02:23                  3.0
# 1        N                        70.0        00:04:02                  3.0
# 2        Y                        10.0        00:02:11                  3.0
# 3        Y                        53.0        00:00:37                  2.0
# 4        Y                        95.0        00:01:00                  3.0

# %%
df.isnull().sum()
# Out:
# Call Id                         0
# Agent                           0
# Date                            0
# Time                            0
# Topic                           0
# Answered (Y/N)                  0
# Resolved                        0
# Speed of answer in seconds    946
# AvgTalkDuration               946
# Satisfaction rating           946
# dtype: int64

# %%
sns.boxplot(df['Speed of answer in seconds'])
# Out:
# <Axes: ylabel='Speed of answer in seconds'>

# %%
sns.boxplot(df['Satisfaction rating'])
# Out:
# <Axes: ylabel='Satisfaction rating'>

# %%
df['Speed of answer in seconds'].fillna(df['Speed of answer in seconds'].mean(), inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8308\329895372.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Speed of answer in seconds'].fillna(df['Speed of answer in seconds'].mean(), inplace=True)

# %%
df['AvgTalkDuration'] = df['AvgTalkDuration'].astype(str)

# %%
df['AvgTalkDuration'] = pd.to_timedelta(df['AvgTalkDuration']).dt.total_seconds()

# %%
df['AvgTalkDuration'].fillna(df['AvgTalkDuration'].median(), inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8308\3755447623.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['AvgTalkDuration'].fillna(df['AvgTalkDuration'].median(), inplace=True)

# %%
df['Satisfaction rating'].fillna(df['Satisfaction rating'].median(), inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8308\1575985367.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Satisfaction rating'].fillna(df['Satisfaction rating'].median(), inplace=True)

# %%
df.head()
# Out:
#   Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0  ID0001    Diane  2021-01-01  09:12:58   Contract related              Y
# 1  ID0002    Becky  2021-01-01  09:12:58  Technical Support              Y
# 2  ID0003  Stewart  2021-01-01  09:47:31   Contract related              Y
# 3  ID0004     Greg  2021-01-01  09:47:31   Contract related              Y
# 4  ID0005    Becky  2021-01-01  10:00:29    Payment related              Y
#
#   Resolved  Speed of answer in seconds  AvgTalkDuration  Satisfaction rating
# 0        Y                       109.0            143.0                  3.0
# 1        N                        70.0            242.0                  3.0
# 2        Y                        10.0            131.0                  3.0
# 3        Y                        53.0             37.0                  2.0
# 4        Y                        95.0             60.0                  3.0

# %%
df.isnull().sum()
# Out:
# Call Id                       0
# Agent                         0
# Date                          0
# Time                          0
# Topic                         0
# Answered (Y/N)                0
# Resolved                      0
# Speed of answer in seconds    0
# AvgTalkDuration               0
# Satisfaction rating           0
# dtype: int64

# %%
df.dtypes
# Out:
# Call Id                        object
# Agent                          object
# Date                           object
# Time                           object
# Topic                          object
# Answered (Y/N)                 object
# Resolved                       object
# Speed of answer in seconds    float64
# AvgTalkDuration               float64
# Satisfaction rating           float64
# dtype: object

# %%
sns.histplot(df['Speed of answer in seconds'])
# Out:
# <Axes: xlabel='Speed of answer in seconds', ylabel='Count'>

# %%
sns.boxplot(x='Agent', y='Speed of answer in seconds', data=df)
# Out:
# <Axes: xlabel='Agent', ylabel='Speed of answer in seconds'>

# %%
sns.countplot(x='Topic', data=df)
# Out:
# <Axes: xlabel='Topic', ylabel='count'>

# %%
sns.barplot(x='Agent', y='Satisfaction rating', data=df)
# Out:
# <Axes: xlabel='Agent', ylabel='Satisfaction rating'>

# %%
sns.scatterplot(x='Speed of answer in seconds', y='Satisfaction rating', data=df)
# Out:
# <Axes: xlabel='Speed of answer in seconds', ylabel='Satisfaction rating'>

# %%
df.corr(numeric_only=True)
# Out:
#                             Speed of answer in seconds  AvgTalkDuration  \
# Speed of answer in seconds                    1.000000        -0.002898
# AvgTalkDuration                              -0.002898         1.000000
# Satisfaction rating                           0.000942        -0.000461
#
#                             Satisfaction rating
# Speed of answer in seconds             0.000942
# AvgTalkDuration                       -0.000461
# Satisfaction rating                    1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.dtypes
# Out:
# Call Id                        object
# Agent                          object
# Date                           object
# Time                           object
# Topic                          object
# Answered (Y/N)                 object
# Resolved                       object
# Speed of answer in seconds    float64
# AvgTalkDuration               float64
# Satisfaction rating           float64
# dtype: object

# %%
df.drop('Call Id', axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le_agent = LabelEncoder()
df['Agent'] = le_agent.fit_transform(df['Agent'])

# %%
from sklearn.preprocessing import LabelEncoder
le_topic = LabelEncoder()
df['Topic'] = le_topic.fit_transform(df['Topic'])

# %%
df.dtypes
# Out:
# Agent                           int32
# Date                           object
# Time                           object
# Topic                           int32
# Answered (Y/N)                 object
# Resolved                       object
# Speed of answer in seconds    float64
# AvgTalkDuration               float64
# Satisfaction rating           float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
df['Answered (Y/N)'] = df['Answered (Y/N)'].map({'Y': 1, 'N': 0})

# %%
from sklearn.preprocessing import LabelEncoder
df['Resolved'] = df['Resolved'].map({'Y': 1, 'N': 0})

# %%
df.dtypes
# Out:
# Agent                           int32
# Date                           object
# Time                           object
# Topic                           int32
# Answered (Y/N)                  int64
# Resolved                        int64
# Speed of answer in seconds    float64
# AvgTalkDuration               float64
# Satisfaction rating           float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Extract numerical time-based features from the Date column
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['DayOfWeek'] = df['Date'].dt.dayofweek   # Monday=0, Sunday=6
df['IsWeekend'] = df['DayOfWeek'].isin([5,6]).astype(int)

# %%
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S').dt.time

# %%
df.drop('Date', axis=1, inplace=True)

# %%
df.dtypes
# Out:
# Agent                           int32
# Time                          float64
# Topic                           int32
# Answered (Y/N)                  int64
# Resolved                        int64
# Speed of answer in seconds    float64
# AvgTalkDuration               float64
# Satisfaction rating           float64
# DayOfWeek                       int32
# Year                            int32
# Month                           int32
# Day                             int32
# IsWeekend                       int32
# dtype: object

# %%
df.head()
# Out:
#    Agent     Time  Topic  Answered (Y/N)  Resolved  \
# 0      2  33178.0      1               1         1
# 1      0  33178.0      4               1         0
# 2      7  35251.0      1               1         1
# 3      3  35251.0      1               1         1
# 4      0  36029.0      2               1         1
#
#    Speed of answer in seconds  AvgTalkDuration  Satisfaction rating  \
# 0                       109.0            143.0                  3.0
# 1                        70.0            242.0                  3.0
# 2                        10.0            131.0                  3.0
# 3                        53.0             37.0                  2.0
# 4                        95.0             60.0                  3.0
#
#    DayOfWeek  Year  Month  Day  IsWeekend
# 0          4  2021      1    1          0
# 1          4  2021      1    1          0
# 2          4  2021      1    1          0
# 3          4  2021      1    1          0
# ...

# %%
df['Time'] = df['Time'].astype(str)

# %%
df['Time'] = pd.to_timedelta(df['Time']).dt.total_seconds()

# %%
df.head()
# Out:
#    Agent       Date     Time  Topic  Answered (Y/N)  Resolved  \
# 0      2 2021-01-01  33178.0      1               1         1
# 1      0 2021-01-01  33178.0      4               1         0
# 2      7 2021-01-01  35251.0      1               1         1
# 3      3 2021-01-01  35251.0      1               1         1
# 4      0 2021-01-01  36029.0      2               1         1
#
#    Speed of answer in seconds  AvgTalkDuration  Satisfaction rating
# 0                       109.0            143.0                  3.0
# 1                        70.0            242.0                  3.0
# 2                        10.0            131.0                  3.0
# 3                        53.0             37.0                  2.0
# 4                        95.0             60.0                  3.0

# %%
df.dtypes
# Out:
# Agent                                  int32
# Date                          datetime64[ns]
# Time                                 float64
# Topic                                  int32
# Answered (Y/N)                         int64
# Resolved                               int64
# Speed of answer in seconds           float64
# AvgTalkDuration                      float64
# Satisfaction rating                  float64
# dtype: object

# %%
ip = df.drop('Resolved',axis=1)
op = df.Resolved

# %%
ip.head()
# Out:
#    Agent     Time  Topic  Answered (Y/N)  Speed of answer in seconds  \
# 0      2  33178.0      1               1                       109.0
# 1      0  33178.0      4               1                        70.0
# 2      7  35251.0      1               1                        10.0
# 3      3  35251.0      1               1                        53.0
# 4      0  36029.0      2               1                        95.0
#
#    AvgTalkDuration  Satisfaction rating  DayOfWeek  Year  Month  Day  \
# 0            143.0                  3.0          4  2021      1    1
# 1            242.0                  3.0          4  2021      1    1
# 2            131.0                  3.0          4  2021      1    1
# 3             37.0                  2.0          4  2021      1    1
# 4             60.0                  3.0          4  2021      1    1
#
#    IsWeekend
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
op.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: Resolved, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(ip,op,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y1 = lr.predict(x_test)

# %%
from sklearn.metrics import f1_score,recall_score,precision_score,accuracy_score
acc = accuracy_score(y1,y_test)
f1 = f1_score(y1,y_test)
pre = precision_score(y1,y_test)
rel = recall_score(y1,y_test)
print('Accuracy :',acc)
print('f1_score :',f1)
print('precision :',pre)
print('Recall :',rel)
# Out:
# Accuracy : 0.913
# f1_score : 0.9427254772876893
# precision : 1.0
# Recall : 0.8916562889165629

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm = confusion_matrix(y1,y_test)
cm
# Out:
# array([[197,   0],
#        [ 87, 716]], dtype=int64)

# %%
cmd = ConfusionMatrixDisplay(cm)
cmd.plot()
plt.show()
